# %% [markdown]
# <a href="https://colab.research.google.com/github/KeerHu73/wrangling/blob/main/lab/lab_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Web Scraping
#
# Lots of great data is available online, but available through inconveniently formatted web pages. When this is the case, sometimes you can simply copy and paste the data into a .csv file and go on with your life. But if there are many records to parse and combine into a dataset, that might be impossible. Can we automate the collection of data from online sources?
#
# This is called web scraping. Broadly speaking: Web scraping is legal, but what you plan to do with the results of your scraping might not be. In general, most sites do not want you to scrape them at this point, but there is not really a way to stop you if you are sufficiently motivated. Be careful to use server resources respectfully (not too many requests per unit time), think seriously about privacy concerns, and be careful who you share your work with and how it is used.
#
# We'll be scraping data about used cars in Charlottesville from Craigslist, particularly this page: https://charlottesville.craigslist.org/search/cta?purveyor=owner#search=1~gallery~0~0

# %% [markdown]
# We'll use the `requests` package to get web pages off the Internet and into Python. Again, we'll use a header with a user-agent that masks our true identity so that we're not rejected by the server. This particular url points to the car listings for Craigslist in Charlottesville. To use requests, you pass a `url` for the page you want and a `header` that controls how you appear to the server to `requests.get`:

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import requests # Page requests

header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:124.0) Gecko/20100101 Firefox/124.0'} # How we wish to appear to CL
url = 'https://charlottesville.craigslist.org/search/cta?purveyor=owner#search=1~gallery~0~0' # The page we want to scrape
raw = requests.get(url,headers=header) # Get page

# %% [markdown]
# Now that we have that particular page available locally, we want to **parse** it and get results from it. To do that, we can use a package called `beautifulSoup` or `bs4`.
#
# What does `beautifulSoup` do for us? Let's go to the web page of interest. You probably see something like this:
#
# ![Listings](./src/craigslist.png "Craigslist")
#
# But if you "view page source" -- which is CTRL+U -- in Chrome, you see what the computer sees:
#
# ![Listings](./src/craigslist_source.png "Craigslist")
#
# Since your web browser needs lots of instructions about how to render the text, pictures, and other content on your web page, there are a lot of clues about where the data live and how to extricate them from a page. These clues are called **tags**. If you wander the source for the search page on cars, you see a particular `class = "cl-static-search-result"` term appear attached to each listing:
#
# ![Listings](./src/listing.png "Craigslist")
#
# This structure can be exploited to search the page for information. This kind of detective work -- looking at the page source, finding the interesting tags, and then searching the page with `beautifulSoup` -- is the basic job of web scraping.
#
# What I do is look at the rendered page, find the text I want and copy it, then search for that text in the HTML code that the computer sees. When I find the text I want, I look for the tag nearby. Here, it's `cl-static-search-result`: That's what I'll want beautifulSoup to search for.

# %% [markdown]
# The following code chunk takes the raw content from `requests` and turns it into a beautifulSoup object, which can search the page and return results for us:

# %%
from bs4 import BeautifulSoup as soup # HTML parser
bsObj = soup(raw.content,'html.parser') # Parse the html
listings = bsObj.find_all(class_="cl-static-search-result") # Find all listings of the kind we want

# %% [markdown]
# Why is the argument `class_` and not just `class`? The word `class` is a reserved keyword for Python, and cannot be used by anyone else, similar to `True` and `False`. But since we want the `class = "cl-static-search-result"` terms, we need to use the `class_` argument to the `.find_all` method.
#
# The `.find_all` function dredges the entire page and finds all the instances of `class = "cl-static-search-result"`, resulting in a list of entries. We can then parse the entries.
#
# Parsing the entries can be a challenge! We have to go back to what a listing looks like, and look at the tags within the listing. They're typically `div` tags with a `class` like price or location. You then have to experiment a bit with `.find` and the HTML to make sure you're getting the information you want. For each listing, the `.find` method to search within the listing record for specific information, but it's typically still wrapped in the tag. To get the real information we want, we can then use `.get_text()`. I end up using a code chunk to experiment and play with a record to make sure I'm getting as close to what I want as possible.
#
# In the code below, two more things happen. You don't need to do them in your work, but they're helpful to know about.
#
# First, I would like to get the brand of the car from the post title, if possible. To do this, I split the title into words using `title.split()`, and then I use a list comprehension to look over every word in the title and check whether it appears in the `brands` list.
#
# Second, I would like to get the year the car was built, if possible, so I can determine the vehicle's age. To do this, I use a thing called **regular expressions** that provides a language for expressing patterns. Do I remember how to do this off the top of my head? No, I read a few pages in a book and looked on StackOverflow for answers. Roughly, in order to express the idea "any year starting with 20xx," you can write `20[0-9][0-9]`, and for "any year starting with 19xx," you can write `19[0-9][0-9]`. The `[0-9]`'s act as wildcards for any digit. This allows me to use the `re` package to find any instances of year-like numbers in the title text, using `re.search(r'20[0-9][0-9]|19[0-9][0-9]', title )`.
#
# This is all nested in a for-loop over the listings, and the data is appended to a list.

# %%
import re # Regular expressions

brands = ['honda', 'dodge','toyota','ford','tesla','gmc','jeep','bmw','mitsubishi','mazda',
          'volvo','audi','volkswagen','chevy','chevrolet','acura','kia','subaru','lexus',
          'cadillac','buick','porsche','infiniti']

data = [] # We'll save our listings in this object
for k in range( len(listings) ):
    title = listings[k].find('div',class_='title').get_text().lower()
    price = listings[k].find('div',class_='price').get_text()
    link = listings[k].find(href=True)['href']
    # Get brand from the title string:
    words = title.split()
    hits = [word for word in words if word in brands] # Find brands in the title
    if len(hits) == 0:
        brand = 'missing'
    else:
        brand = hits[0]
    # Get years from title string:
    regex_search = re.search(r'20[0-9][0-9]|19[0-9][0-9]', title ) # Find year references
    if regex_search is None: # If no hits, record year as missing value
        year = np.nan
    else: # If hits, record year as first match
        year = regex_search.group(0)
    #
    data.append({'title':title,'price':price,'year':year,'link':link,'brand':brand})

# %% [markdown]
# With the data scraped from Craigslist, we can put it in a dataframe and wrangle it. Of course, price and year come in as text, not numbers, and need to be typecast/coerced:

# %%
## Wrangle the data
df = pd.DataFrame.from_dict(data)
df['price'] = df['price'].str.replace('$','')
df['price'] = df['price'].str.replace(',','')
df['price'] = pd.to_numeric(df['price'],errors='coerce')
df['year'] = pd.to_numeric(df['year'],errors='coerce')
df['age'] = 2025-df['year']
print(df.shape)
df.to_csv('./src/craigslist_cville_cars.csv') # Save data in case of a disaster
df.head()
# Out:
# (62, 6)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-5-7ef10fa3adea> in <cell line: 0>()
#       7 df['age'] = 2025-df['year']
#       8 print(df.shape)
# ----> 9 df.to_csv('./src/craigslist_cville_cars.csv') # Save data in case of a disaster
#      10 df.head()
#
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     331                     stacklevel=find_stack_level(),
#     332                 )
# --> 333             return func(*args, **kwargs)
#     334
#     335         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3965         )
#    3966
# -> 3967         return DataFrameRenderer(formatter).to_csv(
#    3968             path_or_buf,
#    3969             lineterminator=lineterminator,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1012             formatter=self.fmt,
#    1013         )
# -> 1014         csv_formatter.save()
#    1015
#    1016         if created_buffer:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/csvs.py in save(self)
#     249         """
#     250         # apply compression and byte/text conversion
# --> 251         with get_handle(
#     252             self.filepath_or_buffer,
#     253             self.mode,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747     # Only for write methods
#     748     if "r" not in mode and is_path:
# --> 749         check_parent_directory(str(handle))
#     750
#     751     if compression:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/common.py in check_parent_directory(path)
#     614     parent = Path(path).parent
#     615     if not parent.is_dir():
# --> 616         raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#     617
#     618
#
# OSError: Cannot save file into a non-existent directory: 'src'

# %% [markdown]
# With the data in and wrangled, we can now do some analysis:

# %%
print(df['price'].describe())
df['price'].hist(grid=False)
plt.show()
print(df['age'].describe())
df['age'].hist(grid=False)
plt.show()
# Out:
# count       62.000000
# mean      9587.887097
# std      10731.142518
# min       2000.000000
# 25%       3412.500000
# 50%       6375.000000
# 75%      10887.500000
# max      62800.000000
# Name: price, dtype: float64
# count    57.000000
# mean     22.140351
# std      14.575467
# min       4.000000
# 25%      13.000000
# 50%      18.000000
# 75%      24.000000
# max      68.000000
# Name: age, dtype: float64

# %%
# Price by brand:
df.loc[:,['price','brand']].groupby('brand').describe()
# Out:
#            price                                                          \
#            count          mean           std      min       25%      50%
# brand
# audi         1.0  37000.000000           NaN  37000.0  37000.00  37000.0
# bmw          3.0  19966.666667  20813.537261   7900.0   7950.00   8000.0
# chevrolet    4.0  10875.000000   9393.038202   3000.0   3375.00   9000.0
# chevy        3.0  11616.666667  11515.677719   4450.0   4975.00   5500.0
# dodge        1.0  18900.000000           NaN  18900.0  18900.00  18900.0
# ford         3.0  21333.333333  29173.332572   3500.0   4500.00   5500.0
# gmc          2.0  16475.000000  13470.384182   6950.0  11712.50  16475.0
# honda        5.0   5629.800000   2372.328013   2300.0   4700.00   5900.0
# jeep         2.0   9500.000000      0.000000   9500.0   9500.00   9500.0
# lexus        2.0  11175.000000    318.198052  10950.0  11062.50  11175.0
# missing     14.0  10089.214286  16148.241324   2000.0   3312.50   4650.0
# mitsubishi   1.0   7300.000000           NaN   7300.0   7300.00   7300.0
# subaru       1.0   3900.000000           NaN   3900.0   3900.00   3900.0
# toyota       4.0   9549.750000   7072.121340   2199.0   4299.75   9500.0
#
#
#                  75%      max
# brand
# audi        37000.00  37000.0
# bmw         26000.00  44000.0
# chevrolet   16500.00  22500.0
# chevy       15200.00  24900.0
# dodge       18900.00  18900.0
# ford        30250.00  55000.0
# gmc         21237.50  26000.0
# honda        6500.00   8749.0
# jeep         9500.00   9500.0
# lexus       11287.50  11400.0
# missing      6749.75  62800.0
# mitsubishi   7300.00   7300.0
# subaru       3900.00   3900.0
# toyota      14750.00  17000.0

# %%
# Age by brand:
df.loc[:,['age','brand']].groupby('brand').describe()
# Out:
#              age
#            count       mean        std   min   25%   50%   75%   max
# brand
# audi         1.0   6.000000        NaN   6.0   6.0   6.0   6.0   6.0
# bmw          2.0  15.000000   1.414214  14.0  14.5  15.0  15.5  16.0
# chevrolet    4.0  44.000000  16.000000  36.0  36.0  36.0  44.0  68.0
# chevy        3.0  20.000000  12.124356   7.0  14.5  22.0  26.5  31.0
# dodge        1.0  27.000000        NaN  27.0  27.0  27.0  27.0  27.0
# ford         3.0  22.666667   1.154701  22.0  22.0  22.0  23.0  24.0
# gmc          1.0  27.000000        NaN  27.0  27.0  27.0  27.0  27.0
# honda        5.0  18.000000   9.000000  10.0  13.0  15.0  19.0  33.0
# jeep         2.0  22.000000  14.142136  12.0  17.0  22.0  27.0  32.0
# lexus        2.0  17.000000   5.656854  13.0  15.0  17.0  19.0  21.0
# missing     11.0  30.636364  23.585049   7.0  12.0  20.0  49.0  68.0
# mitsubishi   1.0  17.000000        NaN  17.0  17.0  17.0  17.0  17.0
# subaru       1.0  11.000000        NaN  11.0  11.0  11.0  11.0  11.0
# toyota       4.0  15.500000   3.109126  12.0  13.5  15.5  17.5  19.0

# %%
ax = sns.scatterplot(data=df, x='age', y='price',hue='brand')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

# %%
df['log_price'] = np.log(df['price'])
df['log_age'] = np.log(df['age'])

ax = sns.scatterplot(data=df, x='log_age', y='log_price',hue='brand')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

print(df.loc[:,['log_price','log_age']].cov())
print(df.loc[:,['log_price','log_age']].corr())
# Out:
#            log_price   log_age
# log_price   0.783367 -0.196806
# log_age    -0.196806  0.382606
#            log_price   log_age
# log_price   1.000000 -0.376511
# log_age    -0.376511  1.000000

# %% [markdown]
# ## The Lab:
#
#
# 1. Pick something else on Craigslist besides used cars: Musical instruments, roommates, antiques, etc. Look at the search page and its source code. Record which fields/data you would like to gather, and what kinds of basic EDA you'd do with it.
# 2. Get your search results of interest using `requests` and extract data from them using `beautifulSoup`, using code similar to what's above.
# 3. Wrangle your data into a dataframe and do some basic descriptions and plots. Try to find some interesting relationships or stories to tell about your data.

# %% [markdown]
# I choose Bikes from the website

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

#Fetch Craigslist Page
import requests #retrieve the bikes listing page
header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:124.0) Gecko/20100101 Firefox/124.0'} # How we wish to appear to CL
url = 'https://charlottesville.craigslist.org/search/bia?purveyor=owner#search=1~gallery~0~0'# The page we want to scrape
raw = requests.get(url,headers=header)

# %% [markdown]
# ![bikes.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![bikes——codes.jpg](data:image/jpeg;base64,...)

# %%
#Parsing HTML with BeacutifulSoup
from bs4 import BeautifulSoup as soup
bsObj= soup(raw.content,'html.parser')
listings =bsObj.find_all(class_="cl-static-search-result")

# %%
#Extracting Data
#Each bike would be classify as brands/types/material/wheel/condition

brands = ['giant', 'trek', 'specialized', 'cannondale', 'scott', 'bianchi', 'merida',
          'cervelo', 'pinarello', 'orbea','santa cruz', 'kona', 'fuji', 'diamondback']

bike_types = ['bmx','cargo/pedicab','road', 'cruiser', 'cyclocross', 'folding', 'gravel', 'hybrid/comfort','kids', 'mountain','recumbent/trike', 'road', 'tandem', 'track', 'unicycle','other']

frame_materials = ['alloy','scandium','aluminum', 'carbon fiber', 'steel', 'titanium', 'composite','other/unknown']

wheel_sizes = ['10 in', '12 in', '14 in', '16 in', '18 in', '20 in', '24 in', '25 in',
               '26 in', '26.5 in', '27 in', '27.5 in', '28 in', '29 in', '650B', '650C', '700C','other/unknown']

conditions = ['new', 'like new', 'excellent', 'good', 'fair', 'salvage']

#Extract Data from Listings
import re #import years

data = [] #we'll save things in this object
for k in range(len(listings)):
    #Extract the title, price, and link
    title = listings[k].find('div', class_='title').get_text().lower()
    price = listings[k].find('div', class_='price').get_text()
    link = listings[k].find(href=True)['href']

    #Extract brand from the title
    words = title.split()
    hits = [word for word in words if word in brands]  # Find brands in the title
    if len(hits) == 0:
        brand = 'missing'
    else:
        brand = hits[0]

    # Extract year from title
    regex_search = re.search(r'20[0-9][0-9]|19[0-9][0-9]', title)
    if regex_search is None:
        year = np.nan
    else:
        year = regex_search.group(0)

    #Extract bike type
    bike_hits = [word for word in words if word in bike_types]
    if len(bike_hits) == 0:
        bike_type = 'missing'
    else:
        bike_type = bike_hits[0]

    #Extract frame material
    material_hits = [word for word in words if word in frame_materials]
    if len(material_hits) == 0:
        frame_material = 'missing'
    else:
        frame_material = material_hits[0]

    #Extract wheel size
    wheel_hits = [word for word in words if word in wheel_sizes]
    if len(wheel_hits) == 0:
        wheel_size = 'missing'
    else:
        wheel_size = wheel_hits[0]

    #Extract condition
    condition_hits = [word for word in words if word in conditions]
    if len(condition_hits) == 0:
        condition = 'missing'
    else:
        condition = condition_hits[0]

    #Append extracted data to the list
    data.append({'title': title, 'price': price, 'year': year, 'link': link, 'brand': brand,
                 'bike_type': bike_type, 'frame_material': frame_material, 'wheel_size': wheel_size,
                 'condition': condition})

#Convert extracted data into a DataFrame
df = pd.DataFrame(data)

#Clean and process the data
df['price'] = df['price'].str.replace('$', '').str.replace(',', '')
df['price'] = pd.to_numeric(df['price'], errors='coerce')
df['year'] = pd.to_numeric(df['year'], errors='coerce')
df['age'] = 2025 - df['year']

#Save the extracted data as a CSV file
df.to_csv('craigslist_bicycles_extended.csv', index=False)
df.head()
# Out:
#                                                title  price    year  \
# 0                2 trek navigator 200 mountain bikes    250     NaN
# 1                 2024 hyper wizard custom bmx build   2400  2024.0
# 2                               giant roam 2 bicycle    190     NaN
# 3  1985 panasonic team america vintage bike w/dur...    450  1985.0
# 4    garneau gros louis 2 fat tire bike - $1,200 obo   1200     NaN
#
#                                                 link    brand bike_type  \
# 0  https://charlottesville.craigslist.org/bik/d/m...     trek  mountain
# 1  https://charlottesville.craigslist.org/bik/d/c...  missing       bmx
# 2  https://charlottesville.craigslist.org/bik/d/c...    giant   missing
# 3  https://charlottesville.craigslist.org/bik/d/c...  missing   missing
# 4  https://charlottesville.craigslist.org/bik/d/c...  missing   missing
#
#   frame_material wheel_size condition   age
# 0        missing    missing   missing   NaN
# 1        missing    missing   missing   1.0
# 2        missing    missing   missing   NaN
# 3        missing    missing   missing  40.0
# 4        missing    missing   missing   NaN

# %%
#Histogram of bicycle prices
print(df['price'].describe())
df['price'].hist(grid=False)
plt.show()

print(df['age'].describe())
df['age'].hist(grid=False)
plt.show()
# Out:
# count      40.000000
# mean      633.450000
# std       872.315602
# min        20.000000
# 25%        85.000000
# 50%       197.500000
# 75%       787.500000
# max      4200.000000
# Name: price, dtype: float64
# count     7.000000
# mean     10.285714
# std      13.511900
# min       1.000000
# 25%       3.000000
# 50%       6.000000
# 75%       9.500000
# max      40.000000
# Name: age, dtype: float64

# %%
#Age and Price by Brand
print(df.loc[:, ['price', 'brand']].groupby('brand').describe())
print(df.loc[:, ['age', 'brand']].groupby('brand').describe())
# Out:
#             price                                                             \
#             count         mean         std     min      25%     50%      75%
# brand
# fuji          3.0   366.333333  462.169161    99.0    99.50   100.0   500.00
# giant         2.0   207.500000   24.748737   190.0   198.75   207.5   216.25
# missing      28.0   553.928571  904.804416    20.0    60.00   167.5   750.00
# pinarello     1.0  1400.000000         NaN  1400.0  1400.00  1400.0  1400.00
# specialized   2.0  1982.000000   24.041631  1965.0  1973.50  1982.0  1990.50
# trek          4.0   737.500000  841.006342   100.0   212.50   450.0   975.00
#
#
#                 max
# brand
# fuji          900.0
# giant         225.0
# missing      4200.0
# pinarello    1400.0
# specialized  1999.0
# trek         1950.0
#               age
#             count       mean        std   min    25%   50%    75%   max
# brand
# fuji          1.0   9.000000        NaN   9.0   9.00   9.0   9.00   9.0
# giant         0.0        NaN        NaN   NaN    NaN   NaN    NaN   NaN
# missing       3.0  14.666667  21.962089   1.0   2.00   3.0  21.50  40.0
# pinarello     0.0        NaN        NaN   NaN    NaN   NaN    NaN   NaN
# specialized   2.0   4.500000   2.121320   3.0   3.75   4.5   5.25   6.0
# trek          1.0  10.000000        NaN  10.0  10.00  10.0  10.00  10.0

# %%
#Price & Age by Bike Type
print(df.loc[:, ['price', 'bike_type']].groupby('bike_type').describe())
print(df.loc[:, ['age', 'bike_type']].groupby('bike_type').describe())
# Out:
#           price                                                           \
#           count         mean         std     min     25%     50%     75%
# bike_type
# bmx         1.0  2400.000000         NaN  2400.0  2400.0  2400.0  2400.0
# cruiser     2.0    60.000000    0.000000    60.0    60.0    60.0    60.0
# kids        1.0   150.000000         NaN   150.0   150.0   150.0   150.0
# missing    28.0   734.571429  935.196293    20.0   100.0   262.5  1050.0
# mountain    6.0   326.666667  335.435041    50.0    77.5   167.5   625.0
# road        2.0    70.000000   42.426407    40.0    55.0    70.0    85.0
#
#
#               max
# bike_type
# bmx        2400.0
# cruiser      60.0
# kids        150.0
# missing    4200.0
# mountain    750.0
# road        100.0
#             age
#           count       mean        std  min   25%  50%   75%   max
# bike_type
# bmx         1.0   1.000000        NaN  1.0  1.00  1.0  1.00   1.0
# cruiser     0.0        NaN        NaN  NaN   NaN  NaN   NaN   NaN
# kids        0.0        NaN        NaN  NaN   NaN  NaN   NaN   NaN
# missing     6.0  11.833333  14.105554  3.0  3.75  7.5  9.75  40.0
# mountain    0.0        NaN        NaN  NaN   NaN  NaN   NaN   NaN
# road        0.0        NaN        NaN  NaN   NaN  NaN   NaN   NaN

# %%
#Price by Frame Material
print(df.loc[:, ['price', 'frame_material']].groupby('frame_material').describe())
# Out:
#                price
#                count    mean         std   min   25%    50%    75%     max
# frame_material
# missing         40.0  633.45  872.315602  20.0  85.0  197.5  787.5  4200.0

# %%
#Price by Condition
print(df.loc[:, ['price', 'condition']].groupby('condition').describe())
# Out:
#           price
#           count        mean         std    min    25%    50%    75%     max
# condition
# missing    39.0  630.461538  883.511441   20.0   85.0  195.0  825.0  4200.0
# new         1.0  750.000000         NaN  750.0  750.0  750.0  750.0   750.0

# %%
#Scatter plot: Price vs. Bicycle Age
sns.scatterplot(data=df, x='age', y='price', hue='brand')
plt.title("Bicycle Price vs. Age by Brand")
plt.show()

# %%
#Scatter plot: Price vs. Bike Type
sns.scatterplot(data=df, x='bike_type', y='price', hue='brand')
plt.xticks(rotation=45)
plt.title("Bicycle Price vs. Type")
plt.show()

# %%
#Scatter plot: Price vs. Frame Material
sns.scatterplot(data=df, x='frame_material', y='price', hue='brand')
plt.xticks(rotation=45)
plt.title("Bicycle Price vs. Frame Material")
plt.show()

# %%
#Scatter plot: Age vs. Frame Material
sns.scatterplot(data=df, x='frame_material', y='age', hue='brand')
plt.xticks(rotation=45)
plt.title("Bicycle Age vs. Frame Material")
plt.show()

# %%
#Scatter plot: Price vs. Condition
sns.scatterplot(data=df, x='condition', y='price', hue='brand')
plt.xticks(rotation=45)
plt.title("Bicycle Price vs. Condition")
plt.show()

# %%
#Scatter plot: Log-Transformed Price vs. Log-Transformed Age
sns.scatterplot(data=df, x='log_age', y='log_price', hue='brand')
plt.title("Log-Transformed Bicycle Age vs. Price")
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.show()

sns.scatterplot(data=df, x='age', y='price', hue='brand')
plt.title("Bicycle Price vs. Age by Brand")
plt.show()

# %% [markdown]
# I started this lab thinking it would be a straightforward project thanks to really clear description of lab codes shown above, but it quickly turned into something much more challenging than I expected. Since bikes have multiple variables—brand, type, frame material, wheel size, and condition—each step of the data analysis became more complicated. Extracting and cleaning the data took longer than planned, and visualizing the relationships between variables required extra effort since I need to create many scatter plots and tables to show their relationships . At times, I felt overwhelmed by the number of details to consider, but as I kept refining the code, I began to see patterns emerging.
#
# One of the most interesting aspects was how different factors influenced bike prices. Carbon fiber bikes were noticeably more expensive, while steel and aluminum models were more common in lower price ranges. Condition also played a big role—new or like-new bikes had significantly higher prices, whereas used ones varied widely, sometimes even overpriced. The relationship between bike age and price was another interesting find. While older bikes generally sold for less, some vintage models still retained high value, suggesting that rarity or brand reputation might affect pricing more than age alone.
#
# Looking at the data, I also realized how inconsistent Craigslist listings can be. Many sellers didn’t include details like bike type or frame material, making certain analyses less reliable. Despite these challenges, working through the dataset gave me a better understanding of how pricing trends work in secondhand markets. If I were to do this again, I might choose a simpler product category, but I’m still proud of the insights I uncovered through this process.
#
# Additionally, thanks to my friend Jessica, she explained this lab requreiment clearly to teach me do step by step, and she gave me many supports when I decided to give up the option of bikes.
